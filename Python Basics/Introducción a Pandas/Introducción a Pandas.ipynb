# %% [markdown]
# # Aspectos básicos

# %%
# pip install pandas
# pip upgrade

import pandas as pd

# %%
# Importar datos

pokemon = pd.read_csv("PokemonData.csv")
#pokemon = pd.read_excel("/content/pokemon_data.xlsx")
#pokemon = pd.read_csv("/content/pokemon_data.txt", delimiter="\t")

pokemon
# Out:
#      Num                   Name    Type1   Type2  HP  ...  SpAtk  SpDef  \
# 0      1              Bulbasaur    Grass  Poison  45  ...     65     65
# 1      2                Ivysaur    Grass  Poison  60  ...     80     80
# 2      3               Venusaur    Grass  Poison  80  ...    100    100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80  ...    122    120
# 4      4             Charmander     Fire     NaN  39  ...     60     50
# ..   ...                    ...      ...     ...  ..  ...    ...    ...
# 795  719                Diancie     Rock   Fairy  50  ...    100    150
# 796  719    DiancieMega Diancie     Rock   Fairy  50  ...    160    110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80  ...    150    130
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80  ...    170    130
# 799  721              Volcanion     Fire   Water  80  ...    130     90
#
#      Speed  Generation  Legendary
# 0       45           1      False
# 1       60           1      False
# 2       80           1      False
# 3       80           1      False
# 4       65           1      False
# ..     ...         ...        ...
# 795     50           6       True
# 796    110           6       True
# 797     70           6       True
# 798     80           6       True
# 799     70           6       True
#
# [800 rows x 12 columns]

# %%
# Revisar tipo de dato

pokemon.dtypes
# Out:
# Num            int64
# Name          object
# Type1         object
# Type2         object
# HP             int64
#                ...
# SpAtk          int64
# SpDef          int64
# Speed          int64
# Generation     int64
# Legendary       bool
# Length: 12, dtype: object

# %%
# Configurar máximo y mínimo de columnas o ancho

#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
#pd.set_option('display.width')
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)

pokemon
# Out:
#      Num                   Name    Type1   Type2  HP  ...  SpAtk  SpDef  \
# 0      1              Bulbasaur    Grass  Poison  45  ...     65     65
# 1      2                Ivysaur    Grass  Poison  60  ...     80     80
# 2      3               Venusaur    Grass  Poison  80  ...    100    100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80  ...    122    120
# 4      4             Charmander     Fire     NaN  39  ...     60     50
# ..   ...                    ...      ...     ...  ..  ...    ...    ...
# 795  719                Diancie     Rock   Fairy  50  ...    100    150
# 796  719    DiancieMega Diancie     Rock   Fairy  50  ...    160    110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80  ...    150    130
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80  ...    170    130
# 799  721              Volcanion     Fire   Water  80  ...    130     90
#
#      Speed  Generation  Legendary
# 0       45           1      False
# 1       60           1      False
# 2       80           1      False
# 3       80           1      False
# 4       65           1      False
# ..     ...         ...        ...
# 795     50           6       True
# 796    110           6       True
# 797     70           6       True
# 798     80           6       True
# 799     70           6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# # Lectura de datos

# %%
# Imprimir las primeras filas

pokemon.head()
# Out:
#    Num                   Name  Type1   Type2  HP  ...  SpAtk  SpDef  Speed  \
# 0    1              Bulbasaur  Grass  Poison  45  ...     65     65     45
# 1    2                Ivysaur  Grass  Poison  60  ...     80     80     60
# 2    3               Venusaur  Grass  Poison  80  ...    100    100     80
# 3    3  VenusaurMega Venusaur  Grass  Poison  80  ...    122    120     80
# 4    4             Charmander   Fire     NaN  39  ...     60     50     65
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False
#
# [5 rows x 12 columns]

# %%
# Imprimir las últimas filas

pokemon.tail(15)
# Out:
#      Num                 Name    Type1  Type2  HP  ...  SpAtk  SpDef  Speed  \
# 785  711  GourgeistSmall Size    Ghost  Grass  55  ...     58     75     99
# 786  711  GourgeistLarge Size    Ghost  Grass  75  ...     58     75     69
# 787  711  GourgeistSuper Size    Ghost  Grass  85  ...     58     75     54
# 788  712             Bergmite      Ice    NaN  55  ...     32     35     28
# 789  713              Avalugg      Ice    NaN  95  ...     44     46     28
# ..   ...                  ...      ...    ...  ..  ...    ...    ...    ...
# 795  719              Diancie     Rock  Fairy  50  ...    100    150     50
# 796  719  DiancieMega Diancie     Rock  Fairy  50  ...    160    110    110
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80  ...    150    130     70
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80  ...    170    130     80
# 799  721            Volcanion     Fire  Water  80  ...    130     90     70
#
#      Generation  Legendary
# 785           6      False
# 786           6      False
# 787           6      False
# 788           6      False
# 789           6      False
# ..          ...        ...
# 795           6       True
# 796           6       True
# 797           6       True
# 798           6       True
# 799           6       True
#
# [15 rows x 12 columns]

# %%
# Ver los encabezados

pokemon.columns
# Out:
# Index(['Num', 'Name', 'Type1', 'Type2', 'HP', 'Attack', 'Defense', 'SpAtk',
#        'SpDef', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Leer columna

#pokemon.Name
pokemon['Name'].head(1)
# Out:
# 0    Bulbasaur
# Name: Name, dtype: object

# %%
# Leer varias columnas

pokemon[['Name', 'HP', 'Legendary']].head(10)
# Out:
#                         Name  HP  Legendary
# 0                  Bulbasaur  45      False
# 1                    Ivysaur  60      False
# 2                   Venusaur  80      False
# 3      VenusaurMega Venusaur  80      False
# 4                 Charmander  39      False
# 5                 Charmeleon  58      False
# 6                  Charizard  78      False
# 7  CharizardMega Charizard X  78      False
# 8  CharizardMega Charizard Y  78      False
# 9                   Squirtle  44      False

# %%
# La sentencia iloc (integer location)
# Sintaxis [fila, columna]

pokemon.iloc[0]
# Out:
# Num                   1
# Name          Bulbasaur
# Type1             Grass
# Type2            Poison
# HP                   45
#                 ...
# SpAtk                65
# SpDef                65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, Length: 12, dtype: object

# %%
pokemon.iloc[15:27]
# Out:
#     Num                   Name   Type1   Type2  HP  ...  SpAtk  SpDef  Speed  \
# 15   12             Butterfree     Bug  Flying  60  ...     90     80     70
# 16   13                 Weedle     Bug  Poison  40  ...     20     20     50
# 17   14                 Kakuna     Bug  Poison  45  ...     25     25     35
# 18   15               Beedrill     Bug  Poison  65  ...     45     80     75
# 19   15  BeedrillMega Beedrill     Bug  Poison  65  ...     15     80    145
# ..  ...                    ...     ...     ...  ..  ...    ...    ...    ...
# 22   18                Pidgeot  Normal  Flying  83  ...     70     70    101
# 23   18    PidgeotMega Pidgeot  Normal  Flying  83  ...    135     80    121
# 24   19                Rattata  Normal     NaN  30  ...     25     35     72
# 25   20               Raticate  Normal     NaN  55  ...     50     70     97
# 26   21                Spearow  Normal  Flying  40  ...     31     31     70
#
#     Generation  Legendary
# 15           1      False
# 16           1      False
# 17           1      False
# 18           1      False
# 19           1      False
# ..         ...        ...
# 22           1      False
# 23           1      False
# 24           1      False
# 25           1      False
# 26           1      False
#
# [12 rows x 12 columns]

# %%
pokemon.iloc[15, 4]
# Out:
# 60

# %%
for index, row in pokemon.iterrows():
  print(index, row[['Name', 'Type1']])
# Out:
# 0 Name     Bulbasaur
# Type1        Grass
# Name: 0, dtype: object
# 1 Name     Ivysaur
# Type1      Grass
# Name: 1, dtype: object
# 2 Name     Venusaur
# Type1       Grass
# Name: 2, dtype: object
# 3 Name     VenusaurMega Venusaur
# Type1                    Grass
# Name: 3, dtype: object
# 4 Name     Charmander
# Type1          Fire
# Name: 4, dtype: object
# 5 Name     Charmeleon
# Type1          Fire
# Name: 5, dtype: object
# 6 Name     Charizard
# Type1         Fire
# Name: 6, dtype: object
# 7 Name     CharizardMega Charizard X
# Type1                         Fire
# Name: 7, dtype: object
# 8 Name     CharizardMega Charizard Y
# Type1                         Fire
# Name: 8, dtype: object
# 9 Name     Squirtle
# Type1       Water
# Name: 9, dtype: object
# 10 Name     Wartortle
# Type1        Water
# Name: 10, dtype: object
# 11 Name     Blastoise
# Type1        Water
# Name: 11, dtype: object
# 12 Name     BlastoiseMega Blastoise
# Type1                      Water
# Name: 12, dtype: object
# 13 Name     Caterpie
# Type1         Bug
# Name: 13, dtype: object
# 14 Name     Metapod
# Type1        Bug
# Name: 14, dtype: object
# 15 Name     Butterfree
# Type1           Bug
# Name: 15, dtype: object
# 16 Name     Weedle
# Type1       Bug
# Name: 16, dtype: object
# 17 Name     Kakuna
# Type1       Bug
# Name: 17, dtype: object
# 18 Name     Beedrill
# Type1         Bug
# Name: 18, dtype: object
# 19 Name     BeedrillMega Beedrill
# Type1                      Bug
# Name: 19, dtype: object
# 20 Name     Pidgey
# Type1    Normal
# Name: 20, dtype: object
# 21 Name     Pidgeotto
# Type1       Normal
# Name: 21, dtype: object
# 22 Name     Pidgeot
# Type1     Normal
# Name: 22, dtype: object
# 23 Name     PidgeotMega Pidgeot
# Type1                 Normal
# Name: 23, dtype: object
# 24 Name     Rattata
# Type1     Normal
# Name: 24, dtype: object
# 25 Name     Raticate
# Type1      Normal
# Name: 25, dtype: object
# 26 Name     Spearow
# Type1     Normal
# Name: 26, dtype: object
# 27 Name     Fearow
# Type1    Normal
# Name: 27, dtype: object
# 28 Name      Ekans
# Type1    Poison
# Name: 28, dtype: object
# 29 Name      Arbok
# Type1    Poison
# Name: 29, dtype: object
# 30 Name      Pikachu
# Type1    Electric
# Name: 30, dtype: object
# 31 Name       Raichu
# Type1    Electric
# Name: 31, dtype: object
# 32 Name     Sandshrew
# Type1       Ground
# Name: 32, dtype: object
# 33 Name     Sandslash
# Type1       Ground
# Name: 33, dtype: object
# 34 Name     Nidoranâ™€
# Type1        Poison
# Name: 34, dtype: object
# 35 Name     Nidorina
# Type1      Poison
# Name: 35, dtype: object
# 36 Name     Nidoqueen
# Type1       Poison
# Name: 36, dtype: object
# 37 Name     Nidoranâ™‚
# Type1        Poison
# Name: 37, dtype: object
# 38 Name     Nidorino
# Type1      Poison
# Name: 38, dtype: object
# 39 Name     Nidoking
# Type1      Poison
# Name: 39, dtype: object
# 40 Name     Clefairy
# Type1       Fairy
# Name: 40, dtype: object
# 41 Name     Clefable
# Type1       Fairy
# Name: 41, dtype: object
# 42 Name     Vulpix
# Type1      Fire
# Name: 42, dtype: object
# 43 Name     Ninetales
# Type1         Fire
# Name: 43, dtype: object
# 44 Name     Jigglypuff
# Type1        Normal
# Name: 44, dtype: object
# 45 Name     Wigglytuff
# Type1        Normal
# Name: 45, dtype: object
# 46 Name      Zubat
# Type1    Poison
# Name: 46, dtype: object
# 47 Name     Golbat
# Type1    Poison
# Name: 47, dtype: object
# 48 Name     Oddish
# Type1     Grass
# Name: 48, dtype: object
# 49 Name     Gloom
# Type1    Grass
# Name: 49, dtype: object
# 50 Name     Vileplume
# Type1        Grass
# Name: 50, dtype: object
# 51 Name     Paras
# Type1      Bug
# Name: 51, dtype: object
# 52 Name     Parasect
# Type1         Bug
# Name: 52, dtype: object
# 53 Name     Venonat
# Type1        Bug
# Name: 53, dtype: object
# 54 Name     Venomoth
# Type1         Bug
# Name: 54, dtype: object
# 55 Name     Diglett
# Type1     Ground
# Name: 55, dtype: object
# 56 Name     Dugtrio
# Type1     Ground
# Name: 56, dtype: object
# 57 Name     Meowth
# Type1    Normal
# Name: 57, dtype: object
# 58 Name     Persian
# Type1     Normal
# Name: 58, dtype: object
# 59 Name     Psyduck
# Type1      Water
# Name: 59, dtype: object
# 60 Name     Golduck
# Type1      Water
# Name: 60, dtype: object
# 61 Name       Mankey
# Type1    Fighting
# Name: 61, dtype: object
# 62 Name     Primeape
# Type1    Fighting
# Name: 62, dtype: object
# 63 Name     Growlithe
# Type1         Fire
# Name: 63, dtype: object
# 64 Name     Arcanine
# Type1        Fire
# Name: 64, dtype: object
# 65 Name     Poliwag
# Type1      Water
# Name: 65, dtype: object
# 66 Name     Poliwhirl
# Type1        Water
# Name: 66, dtype: object
# 67 Name     Poliwrath
# Type1        Water
# Name: 67, dtype: object
# 68 Name        Abra
# Type1    Psychic
# Name: 68, dtype: object
# 69 Name     Kadabra
# Type1    Psychic
# Name: 69, dtype: object
# 70 Name     Alakazam
# Type1     Psychic
# Name: 70, dtype: object
# 71 Name     AlakazamMega Alakazam
# Type1                  Psychic
# Name: 71, dtype: object
# 72 Name       Machop
# Type1    Fighting
# Name: 72, dtype: object
# 73 Name      Machoke
# Type1    Fighting
# Name: 73, dtype: object
# 74 Name      Machamp
# Type1    Fighting
# Name: 74, dtype: object
# 75 Name     Bellsprout
# Type1         Grass
# Name: 75, dtype: object
# 76 Name     Weepinbell
# Type1         Grass
# Name: 76, dtype: object
# 77 Name     Victreebel
# Type1         Grass
# Name: 77, dtype: object
# 78 Name     Tentacool
# Type1        Water
# Name: 78, dtype: object
# 79 Name     Tentacruel
# Type1         Water
# Name: 79, dtype: object
# 80 Name     Geodude
# Type1       Rock
# Name: 80, dtype: object
# 81 Name     Graveler
# Type1        Rock
# Name: 81, dtype: object
# 82 Name     Golem
# Type1     Rock
# Name: 82, dtype: object
# 83 Name     Ponyta
# Type1      Fire
# Name: 83, dtype: object
# 84 Name     Rapidash
# Type1        Fire
# Name: 84, dtype: object
# 85 Name     Slowpoke
# Type1       Water
# Name: 85, dtype: object
# 86 Name     Slowbro
# Type1      Water
# Name: 86, dtype: object
# 87 Name     SlowbroMega Slowbro
# Type1                  Water
# Name: 87, dtype: object
# 88 Name     Magnemite
# Type1     Electric
# Name: 88, dtype: object
# 89 Name     Magneton
# Type1    Electric
# Name: 89, dtype: object
# 90 Name     Farfetch'd
# Type1        Normal
# Name: 90, dtype: object
# 91 Name      Doduo
# Type1    Normal
# Name: 91, dtype: object
# 92 Name     Dodrio
# Type1    Normal
# Name: 92, dtype: object
# 93 Name      Seel
# Type1    Water
# Name: 93, dtype: object
# 94 Name     Dewgong
# Type1      Water
# Name: 94, dtype: object
# 95 Name     Grimer
# Type1    Poison
# Name: 95, dtype: object
# 96 Name        Muk
# Type1    Poison
# Name: 96, dtype: object
# 97 Name     Shellder
# Type1       Water
# Name: 97, dtype: object
# 98 Name     Cloyster
# Type1       Water
# Name: 98, dtype: object
# 99 Name     Gastly
# Type1     Ghost
# Name: 99, dtype: object
# 100 Name     Haunter
# Type1      Ghost
# Name: 100, dtype: object
# 101 Name     Gengar
# Type1     Ghost
# Name: 101, dtype: object
# 102 Name     GengarMega Gengar
# Type1                Ghost
# Name: 102, dtype: object
# 103 Name     Onix
# Type1    Rock
# Name: 103, dtype: object
# 104 Name     Drowzee
# Type1    Psychic
# Name: 104, dtype: object
# 105 Name       Hypno
# Type1    Psychic
# Name: 105, dtype: object
# 106 Name     Krabby
# Type1     Water
# Name: 106, dtype: object
# 107 Name     Kingler
# Type1      Water
# Name: 107, dtype: object
# 108 Name      Voltorb
# Type1    Electric
# Name: 108, dtype: object
# 109 Name     Electrode
# Type1     Electric
# Name: 109, dtype: object
# 110 Name     Exeggcute
# Type1        Grass
# Name: 110, dtype: object
# 111 Name     Exeggutor
# Type1        Grass
# Name: 111, dtype: object
# 112 Name     Cubone
# Type1    Ground
# Name: 112, dtype: object
# 113 Name     Marowak
# Type1     Ground
# Name: 113, dtype: object
# 114 Name     Hitmonlee
# Type1     Fighting
# Name: 114, dtype: object
# 115 Name     Hitmonchan
# Type1      Fighting
# Name: 115, dtype: object
# 116 Name     Lickitung
# Type1       Normal
# Name: 116, dtype: object
# 117 Name     Koffing
# Type1     Poison
# Name: 117, dtype: object
# 118 Name     Weezing
# Type1     Poison
# Name: 118, dtype: object
# 119 Name     Rhyhorn
# Type1     Ground
# Name: 119, dtype: object
# 120 Name     Rhydon
# Type1    Ground
# Name: 120, dtype: object
# 121 Name     Chansey
# Type1     Normal
# Name: 121, dtype: object
# 122 Name     Tangela
# Type1      Grass
# Name: 122, dtype: object
# 123 Name     Kangaskhan
# Type1        Normal
# Name: 123, dtype: object
# 124 Name     KangaskhanMega Kangaskhan
# Type1                       Normal
# Name: 124, dtype: object
# 125 Name     Horsea
# Type1     Water
# Name: 125, dtype: object
# 126 Name     Seadra
# Type1     Water
# Name: 126, dtype: object
# 127 Name     Goldeen
# Type1      Water
# Name: 127, dtype: object
# 128 Name     Seaking
# Type1      Water
# Name: 128, dtype: object
# 129 Name     Staryu
# Type1     Water
# Name: 129, dtype: object
# 130 Name     Starmie
# Type1      Water
# Name: 130, dtype: object
# 131 Name     Mr. Mime
# Type1     Psychic
# Name: 131, dtype: object
# 132 Name     Scyther
# Type1        Bug
# Name: 132, dtype: object
# 133 Name     Jynx
# Type1     Ice
# Name: 133, dtype: object
# 134 Name     Electabuzz
# Type1      Electric
# Name: 134, dtype: object
# 135 Name     Magmar
# Type1      Fire
# Name: 135, dtype: object
# 136 Name     Pinsir
# Type1       Bug
# Name: 136, dtype: object
# 137 Name     PinsirMega Pinsir
# Type1                  Bug
# Name: 137, dtype: object
# 138 Name     Tauros
# Type1    Normal
# Name: 138, dtype: object
# 139 Name     Magikarp
# Type1       Water
# Name: 139, dtype: object
# 140 Name     Gyarados
# Type1       Water
# Name: 140, dtype: object
# 141 Name     GyaradosMega Gyarados
# Type1                    Water
# Name: 141, dtype: object
# 142 Name     Lapras
# Type1     Water
# Name: 142, dtype: object
# 143 Name      Ditto
# Type1    Normal
# Name: 143, dtype: object
# 144 Name      Eevee
# Type1    Normal
# Name: 144, dtype: object
# 145 Name     Vaporeon
# Type1       Water
# Name: 145, dtype: object
# 146 Name      Jolteon
# Type1    Electric
# Name: 146, dtype: object
# 147 Name     Flareon
# Type1       Fire
# Name: 147, dtype: object
# 148 Name     Porygon
# Type1     Normal
# Name: 148, dtype: object
# 149 Name     Omanyte
# Type1       Rock
# Name: 149, dtype: object
# 150 Name     Omastar
# Type1       Rock
# Name: 150, dtype: object
# 151 Name     Kabuto
# Type1      Rock
# Name: 151, dtype: object
# 152 Name     Kabutops
# Type1        Rock
# Name: 152, dtype: object
# 153 Name     Aerodactyl
# Type1          Rock
# Name: 153, dtype: object
# 154 Name     AerodactylMega Aerodactyl
# Type1                         Rock
# Name: 154, dtype: object
# 155 Name     Snorlax
# Type1     Normal
# Name: 155, dtype: object
# 156 Name     Articuno
# Type1         Ice
# Name: 156, dtype: object
# 157 Name       Zapdos
# Type1    Electric
# Name: 157, dtype: object
# 158 Name     Moltres
# Type1       Fire
# Name: 158, dtype: object
# 159 Name     Dratini
# Type1     Dragon
# Name: 159, dtype: object
# 160 Name     Dragonair
# Type1       Dragon
# Name: 160, dtype: object
# 161 Name     Dragonite
# Type1       Dragon
# Name: 161, dtype: object
# 162 Name      Mewtwo
# Type1    Psychic
# Name: 162, dtype: object
# 163 Name     MewtwoMega Mewtwo X
# Type1                Psychic
# Name: 163, dtype: object
# 164 Name     MewtwoMega Mewtwo Y
# Type1                Psychic
# Name: 164, dtype: object
# 165 Name         Mew
# Type1    Psychic
# Name: 165, dtype: object
# 166 Name     Chikorita
# Type1        Grass
# Name: 166, dtype: object
# 167 Name     Bayleef
# Type1      Grass
# Name: 167, dtype: object
# 168 Name     Meganium
# Type1       Grass
# Name: 168, dtype: object
# 169 Name     Cyndaquil
# Type1         Fire
# Name: 169, dtype: object
# 170 Name     Quilava
# Type1       Fire
# Name: 170, dtype: object
# 171 Name     Typhlosion
# Type1          Fire
# Name: 171, dtype: object
# 172 Name     Totodile
# Type1       Water
# Name: 172, dtype: object
# 173 Name     Croconaw
# Type1       Water
# Name: 173, dtype: object
# 174 Name     Feraligatr
# Type1         Water
# Name: 174, dtype: object
# 175 Name     Sentret
# Type1     Normal
# Name: 175, dtype: object
# 176 Name     Furret
# Type1    Normal
# Name: 176, dtype: object
# 177 Name     Hoothoot
# Type1      Normal
# Name: 177, dtype: object
# 178 Name     Noctowl
# Type1     Normal
# Name: 178, dtype: object
# 179 Name     Ledyba
# Type1       Bug
# Name: 179, dtype: object
# 180 Name     Ledian
# Type1       Bug
# Name: 180, dtype: object
# 181 Name     Spinarak
# Type1         Bug
# Name: 181, dtype: object
# 182 Name     Ariados
# Type1        Bug
# Name: 182, dtype: object
# 183 Name     Crobat
# Type1    Poison
# Name: 183, dtype: object
# 184 Name     Chinchou
# Type1       Water
# Name: 184, dtype: object
# 185 Name     Lanturn
# Type1      Water
# Name: 185, dtype: object
# 186 Name        Pichu
# Type1    Electric
# Name: 186, dtype: object
# 187 Name     Cleffa
# Type1     Fairy
# Name: 187, dtype: object
# 188 Name     Igglybuff
# Type1       Normal
# Name: 188, dtype: object
# 189 Name     Togepi
# Type1     Fairy
# Name: 189, dtype: object
# 190 Name     Togetic
# Type1      Fairy
# Name: 190, dtype: object
# 191 Name        Natu
# Type1    Psychic
# Name: 191, dtype: object
# 192 Name        Xatu
# Type1    Psychic
# Name: 192, dtype: object
# 193 Name       Mareep
# Type1    Electric
# Name: 193, dtype: object
# 194 Name      Flaaffy
# Type1    Electric
# Name: 194, dtype: object
# 195 Name     Ampharos
# Type1    Electric
# Name: 195, dtype: object
# 196 Name     AmpharosMega Ampharos
# Type1                 Electric
# Name: 196, dtype: object
# 197 Name     Bellossom
# Type1        Grass
# Name: 197, dtype: object
# 198 Name     Marill
# Type1     Water
# Name: 198, dtype: object
# 199 Name     Azumarill
# Type1        Water
# Name: 199, dtype: object
# 200 Name     Sudowoodo
# Type1         Rock
# Name: 200, dtype: object
# 201 Name     Politoed
# Type1       Water
# Name: 201, dtype: object
# 202 Name     Hoppip
# Type1     Grass
# Name: 202, dtype: object
# 203 Name     Skiploom
# Type1       Grass
# Name: 203, dtype: object
# 204 Name     Jumpluff
# Type1       Grass
# Name: 204, dtype: object
# 205 Name      Aipom
# Type1    Normal
# Name: 205, dtype: object
# 206 Name     Sunkern
# Type1      Grass
# Name: 206, dtype: object
# 207 Name     Sunflora
# Type1       Grass
# Name: 207, dtype: object
# 208 Name     Yanma
# Type1      Bug
# Name: 208, dtype: object
# 209 Name     Wooper
# Type1     Water
# Name: 209, dtype: object
# 210 Name     Quagsire
# Type1       Water
# Name: 210, dtype: object
# 211 Name      Espeon
# Type1    Psychic
# Name: 211, dtype: object
# 212 Name     Umbreon
# Type1       Dark
# Name: 212, dtype: object
# 213 Name     Murkrow
# Type1       Dark
# Name: 213, dtype: object
# 214 Name     Slowking
# Type1       Water
# Name: 214, dtype: object
# 215 Name     Misdreavus
# Type1         Ghost
# Name: 215, dtype: object
# 216 Name       Unown
# Type1    Psychic
# Name: 216, dtype: object
# 217 Name     Wobbuffet
# Type1      Psychic
# Name: 217, dtype: object
# 218 Name     Girafarig
# Type1       Normal
# Name: 218, dtype: object
# 219 Name     Pineco
# Type1       Bug
# Name: 219, dtype: object
# 220 Name     Forretress
# Type1           Bug
# Name: 220, dtype: object
# 221 Name     Dunsparce
# Type1       Normal
# Name: 221, dtype: object
# 222 Name     Gligar
# Type1    Ground
# Name: 222, dtype: object
# 223 Name     Steelix
# Type1      Steel
# Name: 223, dtype: object
# 224 Name     SteelixMega Steelix
# Type1                  Steel
# Name: 224, dtype: object
# 225 Name     Snubbull
# Type1       Fairy
# Name: 225, dtype: object
# 226 Name     Granbull
# Type1       Fairy
# Name: 226, dtype: object
# 227 Name     Qwilfish
# Type1       Water
# Name: 227, dtype: object
# 228 Name     Scizor
# Type1       Bug
# Name: 228, dtype: object
# 229 Name     ScizorMega Scizor
# Type1                  Bug
# Name: 229, dtype: object
# 230 Name     Shuckle
# Type1        Bug
# Name: 230, dtype: object
# 231 Name     Heracross
# Type1          Bug
# Name: 231, dtype: object
# 232 Name     HeracrossMega Heracross
# Type1                        Bug
# Name: 232, dtype: object
# 233 Name     Sneasel
# Type1       Dark
# Name: 233, dtype: object
# 234 Name     Teddiursa
# Type1       Normal
# Name: 234, dtype: object
# 235 Name     Ursaring
# Type1      Normal
# Name: 235, dtype: object
# 236 Name     Slugma
# Type1      Fire
# Name: 236, dtype: object
# 237 Name     Magcargo
# Type1        Fire
# Name: 237, dtype: object
# 238 Name     Swinub
# Type1       Ice
# Name: 238, dtype: object
# 239 Name     Piloswine
# Type1          Ice
# Name: 239, dtype: object
# 240 Name     Corsola
# Type1      Water
# Name: 240, dtype: object
# 241 Name     Remoraid
# Type1       Water
# Name: 241, dtype: object
# 242 Name     Octillery
# Type1        Water
# Name: 242, dtype: object
# 243 Name     Delibird
# Type1         Ice
# Name: 243, dtype: object
# 244 Name     Mantine
# Type1      Water
# Name: 244, dtype: object
# 245 Name     Skarmory
# Type1       Steel
# Name: 245, dtype: object
# 246 Name     Houndour
# Type1        Dark
# Name: 246, dtype: object
# 247 Name     Houndoom
# Type1        Dark
# Name: 247, dtype: object
# 248 Name     HoundoomMega Houndoom
# Type1                     Dark
# Name: 248, dtype: object
# 249 Name     Kingdra
# Type1      Water
# Name: 249, dtype: object
# 250 Name     Phanpy
# Type1    Ground
# Name: 250, dtype: object
# 251 Name     Donphan
# Type1     Ground
# Name: 251, dtype: object
# 252 Name     Porygon2
# Type1      Normal
# Name: 252, dtype: object
# 253 Name     Stantler
# Type1      Normal
# Name: 253, dtype: object
# 254 Name     Smeargle
# Type1      Normal
# Name: 254, dtype: object
# 255 Name      Tyrogue
# Type1    Fighting
# Name: 255, dtype: object
# 256 Name     Hitmontop
# Type1     Fighting
# Name: 256, dtype: object
# 257 Name     Smoochum
# Type1         Ice
# Name: 257, dtype: object
# 258 Name       Elekid
# Type1    Electric
# Name: 258, dtype: object
# 259 Name     Magby
# Type1     Fire
# Name: 259, dtype: object
# 260 Name     Miltank
# Type1     Normal
# Name: 260, dtype: object
# 261 Name     Blissey
# Type1     Normal
# Name: 261, dtype: object
# 262 Name       Raikou
# Type1    Electric
# Name: 262, dtype: object
# 263 Name     Entei
# Type1     Fire
# Name: 263, dtype: object
# 264 Name     Suicune
# Type1      Water
# Name: 264, dtype: object
# 265 Name     Larvitar
# Type1        Rock
# Name: 265, dtype: object
# 266 Name     Pupitar
# Type1       Rock
# Name: 266, dtype: object
# 267 Name     Tyranitar
# Type1         Rock
# Name: 267, dtype: object
# 268 Name     TyranitarMega Tyranitar
# Type1                       Rock
# Name: 268, dtype: object
# 269 Name       Lugia
# Type1    Psychic
# Name: 269, dtype: object
# 270 Name     Ho-oh
# Type1     Fire
# Name: 270, dtype: object
# 271 Name      Celebi
# Type1    Psychic
# Name: 271, dtype: object
# 272 Name     Treecko
# Type1      Grass
# Name: 272, dtype: object
# 273 Name     Grovyle
# Type1      Grass
# Name: 273, dtype: object
# 274 Name     Sceptile
# Type1       Grass
# Name: 274, dtype: object
# 275 Name     SceptileMega Sceptile
# Type1                    Grass
# Name: 275, dtype: object
# 276 Name     Torchic
# Type1       Fire
# Name: 276, dtype: object
# 277 Name     Combusken
# Type1         Fire
# Name: 277, dtype: object
# 278 Name     Blaziken
# Type1        Fire
# Name: 278, dtype: object
# 279 Name     BlazikenMega Blaziken
# Type1                     Fire
# Name: 279, dtype: object
# 280 Name     Mudkip
# Type1     Water
# Name: 280, dtype: object
# 281 Name     Marshtomp
# Type1        Water
# Name: 281, dtype: object
# 282 Name     Swampert
# Type1       Water
# Name: 282, dtype: object
# 283 Name     SwampertMega Swampert
# Type1                    Water
# Name: 283, dtype: object
# 284 Name     Poochyena
# Type1         Dark
# Name: 284, dtype: object
# 285 Name     Mightyena
# Type1         Dark
# Name: 285, dtype: object
# 286 Name     Zigzagoon
# Type1       Normal
# Name: 286, dtype: object
# 287 Name     Linoone
# Type1     Normal
# Name: 287, dtype: object
# 288 Name     Wurmple
# Type1        Bug
# Name: 288, dtype: object
# 289 Name     Silcoon
# Type1        Bug
# Name: 289, dtype: object
# 290 Name     Beautifly
# Type1          Bug
# Name: 290, dtype: object
# 291 Name     Cascoon
# Type1        Bug
# Name: 291, dtype: object
# 292 Name     Dustox
# Type1       Bug
# Name: 292, dtype: object
# 293 Name     Lotad
# Type1    Water
# Name: 293, dtype: object
# 294 Name     Lombre
# Type1     Water
# Name: 294, dtype: object
# 295 Name     Ludicolo
# Type1       Water
# Name: 295, dtype: object
# 296 Name     Seedot
# Type1     Grass
# Name: 296, dtype: object
# 297 Name     Nuzleaf
# Type1      Grass
# Name: 297, dtype: object
# 298 Name     Shiftry
# Type1      Grass
# Name: 298, dtype: object
# 299 Name     Taillow
# Type1     Normal
# Name: 299, dtype: object
# 300 Name     Swellow
# Type1     Normal
# Name: 300, dtype: object
# 301 Name     Wingull
# Type1      Water
# Name: 301, dtype: object
# 302 Name     Pelipper
# Type1       Water
# Name: 302, dtype: object
# 303 Name       Ralts
# Type1    Psychic
# Name: 303, dtype: object
# 304 Name      Kirlia
# Type1    Psychic
# Name: 304, dtype: object
# 305 Name     Gardevoir
# Type1      Psychic
# Name: 305, dtype: object
# 306 Name     GardevoirMega Gardevoir
# Type1                    Psychic
# Name: 306, dtype: object
# 307 Name     Surskit
# Type1        Bug
# Name: 307, dtype: object
# 308 Name     Masquerain
# Type1           Bug
# Name: 308, dtype: object
# 309 Name     Shroomish
# Type1        Grass
# Name: 309, dtype: object
# 310 Name     Breloom
# Type1      Grass
# Name: 310, dtype: object
# 311 Name     Slakoth
# Type1     Normal
# Name: 311, dtype: object
# 312 Name     Vigoroth
# Type1      Normal
# Name: 312, dtype: object
# 313 Name     Slaking
# Type1     Normal
# Name: 313, dtype: object
# 314 Name     Nincada
# Type1        Bug
# Name: 314, dtype: object
# 315 Name     Ninjask
# Type1        Bug
# Name: 315, dtype: object
# 316 Name     Shedinja
# Type1         Bug
# Name: 316, dtype: object
# 317 Name     Whismur
# Type1     Normal
# Name: 317, dtype: object
# 318 Name     Loudred
# Type1     Normal
# Name: 318, dtype: object
# 319 Name     Exploud
# Type1     Normal
# Name: 319, dtype: object
# 320 Name     Makuhita
# Type1    Fighting
# Name: 320, dtype: object
# 321 Name     Hariyama
# Type1    Fighting
# Name: 321, dtype: object
# 322 Name     Azurill
# Type1     Normal
# Name: 322, dtype: object
# 323 Name     Nosepass
# Type1        Rock
# Name: 323, dtype: object
# 324 Name     Skitty
# Type1    Normal
# Name: 324, dtype: object
# 325 Name     Delcatty
# Type1      Normal
# Name: 325, dtype: object
# 326 Name     Sableye
# Type1       Dark
# Name: 326, dtype: object
# 327 Name     SableyeMega Sableye
# Type1                   Dark
# Name: 327, dtype: object
# 328 Name     Mawile
# Type1     Steel
# Name: 328, dtype: object
# 329 Name     MawileMega Mawile
# Type1                Steel
# Name: 329, dtype: object
# 330 Name      Aron
# Type1    Steel
# Name: 330, dtype: object
# 331 Name     Lairon
# Type1     Steel
# Name: 331, dtype: object
# 332 Name     Aggron
# Type1     Steel
# Name: 332, dtype: object
# 333 Name     AggronMega Aggron
# Type1                Steel
# Name: 333, dtype: object
# 334 Name     Meditite
# Type1    Fighting
# Name: 334, dtype: object
# 335 Name     Medicham
# Type1    Fighting
# Name: 335, dtype: object
# 336 Name     MedichamMega Medicham
# Type1                 Fighting
# Name: 336, dtype: object
# 337 Name     Electrike
# Type1     Electric
# Name: 337, dtype: object
# 338 Name     Manectric
# Type1     Electric
# Name: 338, dtype: object
# 339 Name     ManectricMega Manectric
# Type1                   Electric
# Name: 339, dtype: object
# 340 Name       Plusle
# Type1    Electric
# Name: 340, dtype: object
# 341 Name        Minun
# Type1    Electric
# Name: 341, dtype: object
# 342 Name     Volbeat
# Type1        Bug
# Name: 342, dtype: object
# 343 Name     Illumise
# Type1         Bug
# Name: 343, dtype: object
# 344 Name     Roselia
# Type1      Grass
# Name: 344, dtype: object
# 345 Name     Gulpin
# Type1    Poison
# Name: 345, dtype: object
# 346 Name     Swalot
# Type1    Poison
# Name: 346, dtype: object
# 347 Name     Carvanha
# Type1       Water
# Name: 347, dtype: object
# 348 Name     Sharpedo
# Type1       Water
# Name: 348, dtype: object
# 349 Name     SharpedoMega Sharpedo
# Type1                    Water
# Name: 349, dtype: object
# 350 Name     Wailmer
# Type1      Water
# Name: 350, dtype: object
# 351 Name     Wailord
# Type1      Water
# Name: 351, dtype: object
# 352 Name     Numel
# Type1     Fire
# Name: 352, dtype: object
# 353 Name     Camerupt
# Type1        Fire
# Name: 353, dtype: object
# 354 Name     CameruptMega Camerupt
# Type1                     Fire
# Name: 354, dtype: object
# 355 Name     Torkoal
# Type1       Fire
# Name: 355, dtype: object
# 356 Name      Spoink
# Type1    Psychic
# Name: 356, dtype: object
# 357 Name     Grumpig
# Type1    Psychic
# Name: 357, dtype: object
# 358 Name     Spinda
# Type1    Normal
# Name: 358, dtype: object
# 359 Name     Trapinch
# Type1      Ground
# Name: 359, dtype: object
# 360 Name     Vibrava
# Type1     Ground
# Name: 360, dtype: object
# 361 Name     Flygon
# Type1    Ground
# Name: 361, dtype: object
# 362 Name     Cacnea
# Type1     Grass
# Name: 362, dtype: object
# 363 Name     Cacturne
# Type1       Grass
# Name: 363, dtype: object
# 364 Name     Swablu
# Type1    Normal
# Name: 364, dtype: object
# 365 Name     Altaria
# Type1     Dragon
# Name: 365, dtype: object
# 366 Name     AltariaMega Altaria
# Type1                 Dragon
# Name: 366, dtype: object
# 367 Name     Zangoose
# Type1      Normal
# Name: 367, dtype: object
# 368 Name     Seviper
# Type1     Poison
# Name: 368, dtype: object
# 369 Name     Lunatone
# Type1        Rock
# Name: 369, dtype: object
# 370 Name     Solrock
# Type1       Rock
# Name: 370, dtype: object
# 371 Name     Barboach
# Type1       Water
# Name: 371, dtype: object
# 372 Name     Whiscash
# Type1       Water
# Name: 372, dtype: object
# 373 Name     Corphish
# Type1       Water
# Name: 373, dtype: object
# 374 Name     Crawdaunt
# Type1        Water
# Name: 374, dtype: object
# 375 Name     Baltoy
# Type1    Ground
# Name: 375, dtype: object
# 376 Name     Claydol
# Type1     Ground
# Name: 376, dtype: object
# 377 Name     Lileep
# Type1      Rock
# Name: 377, dtype: object
# 378 Name     Cradily
# Type1       Rock
# Name: 378, dtype: object
# 379 Name     Anorith
# Type1       Rock
# Name: 379, dtype: object
# 380 Name     Armaldo
# Type1       Rock
# Name: 380, dtype: object
# 381 Name     Feebas
# Type1     Water
# Name: 381, dtype: object
# 382 Name     Milotic
# Type1      Water
# Name: 382, dtype: object
# 383 Name     Castform
# Type1      Normal
# Name: 383, dtype: object
# 384 Name     Kecleon
# Type1     Normal
# Name: 384, dtype: object
# 385 Name     Shuppet
# Type1      Ghost
# Name: 385, dtype: object
# 386 Name     Banette
# Type1      Ghost
# Name: 386, dtype: object
# 387 Name     BanetteMega Banette
# Type1                  Ghost
# Name: 387, dtype: object
# 388 Name     Duskull
# Type1      Ghost
# Name: 388, dtype: object
# 389 Name     Dusclops
# Type1       Ghost
# Name: 389, dtype: object
# 390 Name     Tropius
# Type1      Grass
# Name: 390, dtype: object
# 391 Name     Chimecho
# Type1     Psychic
# Name: 391, dtype: object
# 392 Name     Absol
# Type1     Dark
# Name: 392, dtype: object
# 393 Name     AbsolMega Absol
# Type1               Dark
# Name: 393, dtype: object
# 394 Name      Wynaut
# Type1    Psychic
# Name: 394, dtype: object
# 395 Name     Snorunt
# Type1        Ice
# Name: 395, dtype: object
# 396 Name     Glalie
# Type1       Ice
# Name: 396, dtype: object
# 397 Name     GlalieMega Glalie
# Type1                  Ice
# Name: 397, dtype: object
# 398 Name     Spheal
# Type1       Ice
# Name: 398, dtype: object
# 399 Name     Sealeo
# Type1       Ice
# Name: 399, dtype: object
# 400 Name     Walrein
# Type1        Ice
# Name: 400, dtype: object
# 401 Name     Clamperl
# Type1       Water
# Name: 401, dtype: object
# 402 Name     Huntail
# Type1      Water
# Name: 402, dtype: object
# 403 Name     Gorebyss
# Type1       Water
# Name: 403, dtype: object
# 404 Name     Relicanth
# Type1        Water
# Name: 404, dtype: object
# 405 Name     Luvdisc
# Type1      Water
# Name: 405, dtype: object
# 406 Name      Bagon
# Type1    Dragon
# Name: 406, dtype: object
# 407 Name     Shelgon
# Type1     Dragon
# Name: 407, dtype: object
# 408 Name     Salamence
# Type1       Dragon
# Name: 408, dtype: object
# 409 Name     SalamenceMega Salamence
# Type1                     Dragon
# Name: 409, dtype: object
# 410 Name     Beldum
# Type1     Steel
# Name: 410, dtype: object
# 411 Name     Metang
# Type1     Steel
# Name: 411, dtype: object
# 412 Name     Metagross
# Type1        Steel
# Name: 412, dtype: object
# 413 Name     MetagrossMega Metagross
# Type1                      Steel
# Name: 413, dtype: object
# 414 Name     Regirock
# Type1        Rock
# Name: 414, dtype: object
# 415 Name     Regice
# Type1       Ice
# Name: 415, dtype: object
# 416 Name     Registeel
# Type1        Steel
# Name: 416, dtype: object
# 417 Name     Latias
# Type1    Dragon
# Name: 417, dtype: object
# 418 Name     LatiasMega Latias
# Type1               Dragon
# Name: 418, dtype: object
# 419 Name     Latios
# Type1    Dragon
# Name: 419, dtype: object
# 420 Name     LatiosMega Latios
# Type1               Dragon
# Name: 420, dtype: object
# 421 Name     Kyogre
# Type1     Water
# Name: 421, dtype: object
# 422 Name     KyogrePrimal Kyogre
# Type1                  Water
# Name: 422, dtype: object
# 423 Name     Groudon
# Type1     Ground
# Name: 423, dtype: object
# 424 Name     GroudonPrimal Groudon
# Type1                   Ground
# Name: 424, dtype: object
# 425 Name     Rayquaza
# Type1      Dragon
# Name: 425, dtype: object
# 426 Name     RayquazaMega Rayquaza
# Type1                   Dragon
# Name: 426, dtype: object
# 427 Name     Jirachi
# Type1      Steel
# Name: 427, dtype: object
# 428 Name     DeoxysNormal Forme
# Type1               Psychic
# Name: 428, dtype: object
# 429 Name     DeoxysAttack Forme
# Type1               Psychic
# Name: 429, dtype: object
# 430 Name     DeoxysDefense Forme
# Type1                Psychic
# Name: 430, dtype: object
# 431 Name     DeoxysSpeed Forme
# Type1              Psychic
# Name: 431, dtype: object
# 432 Name     Turtwig
# Type1      Grass
# Name: 432, dtype: object
# 433 Name     Grotle
# Type1     Grass
# Name: 433, dtype: object
# 434 Name     Torterra
# Type1       Grass
# Name: 434, dtype: object
# 435 Name     Chimchar
# Type1        Fire
# Name: 435, dtype: object
# 436 Name     Monferno
# Type1        Fire
# Name: 436, dtype: object
# 437 Name     Infernape
# Type1         Fire
# Name: 437, dtype: object
# 438 Name     Piplup
# Type1     Water
# Name: 438, dtype: object
# 439 Name     Prinplup
# Type1       Water
# Name: 439, dtype: object
# 440 Name     Empoleon
# Type1       Water
# Name: 440, dtype: object
# 441 Name     Starly
# Type1    Normal
# Name: 441, dtype: object
# 442 Name     Staravia
# Type1      Normal
# Name: 442, dtype: object
# 443 Name     Staraptor
# Type1       Normal
# Name: 443, dtype: object
# 444 Name     Bidoof
# Type1    Normal
# Name: 444, dtype: object
# 445 Name     Bibarel
# Type1     Normal
# Name: 445, dtype: object
# 446 Name     Kricketot
# Type1          Bug
# Name: 446, dtype: object
# 447 Name     Kricketune
# Type1           Bug
# Name: 447, dtype: object
# 448 Name        Shinx
# Type1    Electric
# Name: 448, dtype: object
# 449 Name        Luxio
# Type1    Electric
# Name: 449, dtype: object
# 450 Name       Luxray
# Type1    Electric
# Name: 450, dtype: object
# 451 Name     Budew
# Type1    Grass
# Name: 451, dtype: object
# 452 Name     Roserade
# Type1       Grass
# Name: 452, dtype: object
# 453 Name     Cranidos
# Type1        Rock
# Name: 453, dtype: object
# 454 Name     Rampardos
# Type1         Rock
# Name: 454, dtype: object
# 455 Name     Shieldon
# Type1        Rock
# Name: 455, dtype: object
# 456 Name     Bastiodon
# Type1         Rock
# Name: 456, dtype: object
# 457 Name     Burmy
# Type1      Bug
# Name: 457, dtype: object
# 458 Name     WormadamPlant Cloak
# Type1                    Bug
# Name: 458, dtype: object
# 459 Name     WormadamSandy Cloak
# Type1                    Bug
# Name: 459, dtype: object
# 460 Name     WormadamTrash Cloak
# Type1                    Bug
# Name: 460, dtype: object
# 461 Name     Mothim
# Type1       Bug
# Name: 461, dtype: object
# 462 Name     Combee
# Type1       Bug
# Name: 462, dtype: object
# 463 Name     Vespiquen
# Type1          Bug
# Name: 463, dtype: object
# 464 Name     Pachirisu
# Type1     Electric
# Name: 464, dtype: object
# 465 Name     Buizel
# Type1     Water
# Name: 465, dtype: object
# 466 Name     Floatzel
# Type1       Water
# Name: 466, dtype: object
# 467 Name     Cherubi
# Type1      Grass
# Name: 467, dtype: object
# 468 Name     Cherrim
# Type1      Grass
# Name: 468, dtype: object
# 469 Name     Shellos
# Type1      Water
# Name: 469, dtype: object
# 470 Name     Gastrodon
# Type1        Water
# Name: 470, dtype: object
# 471 Name     Ambipom
# Type1     Normal
# Name: 471, dtype: object
# 472 Name     Drifloon
# Type1       Ghost
# Name: 472, dtype: object
# 473 Name     Drifblim
# Type1       Ghost
# Name: 473, dtype: object
# 474 Name     Buneary
# Type1     Normal
# Name: 474, dtype: object
# 475 Name     Lopunny
# Type1     Normal
# Name: 475, dtype: object
# 476 Name     LopunnyMega Lopunny
# Type1                 Normal
# Name: 476, dtype: object
# 477 Name     Mismagius
# Type1        Ghost
# Name: 477, dtype: object
# 478 Name     Honchkrow
# Type1         Dark
# Name: 478, dtype: object
# 479 Name     Glameow
# Type1     Normal
# Name: 479, dtype: object
# 480 Name     Purugly
# Type1     Normal
# Name: 480, dtype: object
# 481 Name     Chingling
# Type1      Psychic
# Name: 481, dtype: object
# 482 Name     Stunky
# Type1    Poison
# Name: 482, dtype: object
# 483 Name     Skuntank
# Type1      Poison
# Name: 483, dtype: object
# 484 Name     Bronzor
# Type1      Steel
# Name: 484, dtype: object
# 485 Name     Bronzong
# Type1       Steel
# Name: 485, dtype: object
# 486 Name     Bonsly
# Type1      Rock
# Name: 486, dtype: object
# 487 Name     Mime Jr.
# Type1     Psychic
# Name: 487, dtype: object
# 488 Name     Happiny
# Type1     Normal
# Name: 488, dtype: object
# 489 Name     Chatot
# Type1    Normal
# Name: 489, dtype: object
# 490 Name     Spiritomb
# Type1        Ghost
# Name: 490, dtype: object
# 491 Name      Gible
# Type1    Dragon
# Name: 491, dtype: object
# 492 Name     Gabite
# Type1    Dragon
# Name: 492, dtype: object
# 493 Name     Garchomp
# Type1      Dragon
# Name: 493, dtype: object
# 494 Name     GarchompMega Garchomp
# Type1                   Dragon
# Name: 494, dtype: object
# 495 Name     Munchlax
# Type1      Normal
# Name: 495, dtype: object
# 496 Name        Riolu
# Type1    Fighting
# Name: 496, dtype: object
# 497 Name      Lucario
# Type1    Fighting
# Name: 497, dtype: object
# 498 Name     LucarioMega Lucario
# Type1               Fighting
# Name: 498, dtype: object
# 499 Name     Hippopotas
# Type1        Ground
# Name: 499, dtype: object
# 500 Name     Hippowdon
# Type1       Ground
# Name: 500, dtype: object
# 501 Name     Skorupi
# Type1     Poison
# Name: 501, dtype: object
# 502 Name     Drapion
# Type1     Poison
# Name: 502, dtype: object
# 503 Name     Croagunk
# Type1      Poison
# Name: 503, dtype: object
# 504 Name     Toxicroak
# Type1       Poison
# Name: 504, dtype: object
# 505 Name     Carnivine
# Type1        Grass
# Name: 505, dtype: object
# 506 Name     Finneon
# Type1      Water
# Name: 506, dtype: object
# 507 Name     Lumineon
# Type1       Water
# Name: 507, dtype: object
# 508 Name     Mantyke
# Type1      Water
# Name: 508, dtype: object
# 509 Name     Snover
# Type1     Grass
# Name: 509, dtype: object
# 510 Name     Abomasnow
# Type1        Grass
# Name: 510, dtype: object
# 511 Name     AbomasnowMega Abomasnow
# Type1                      Grass
# Name: 511, dtype: object
# 512 Name     Weavile
# Type1       Dark
# Name: 512, dtype: object
# 513 Name     Magnezone
# Type1     Electric
# Name: 513, dtype: object
# 514 Name     Lickilicky
# Type1        Normal
# Name: 514, dtype: object
# 515 Name     Rhyperior
# Type1       Ground
# Name: 515, dtype: object
# 516 Name     Tangrowth
# Type1        Grass
# Name: 516, dtype: object
# 517 Name     Electivire
# Type1      Electric
# Name: 517, dtype: object
# 518 Name     Magmortar
# Type1         Fire
# Name: 518, dtype: object
# 519 Name     Togekiss
# Type1       Fairy
# Name: 519, dtype: object
# 520 Name     Yanmega
# Type1        Bug
# Name: 520, dtype: object
# 521 Name     Leafeon
# Type1      Grass
# Name: 521, dtype: object
# 522 Name     Glaceon
# Type1        Ice
# Name: 522, dtype: object
# 523 Name     Gliscor
# Type1     Ground
# Name: 523, dtype: object
# 524 Name     Mamoswine
# Type1          Ice
# Name: 524, dtype: object
# 525 Name     Porygon-Z
# Type1       Normal
# Name: 525, dtype: object
# 526 Name     Gallade
# Type1    Psychic
# Name: 526, dtype: object
# 527 Name     GalladeMega Gallade
# Type1                Psychic
# Name: 527, dtype: object
# 528 Name     Probopass
# Type1         Rock
# Name: 528, dtype: object
# 529 Name     Dusknoir
# Type1       Ghost
# Name: 529, dtype: object
# 530 Name     Froslass
# Type1         Ice
# Name: 530, dtype: object
# 531 Name        Rotom
# Type1    Electric
# Name: 531, dtype: object
# 532 Name     RotomHeat Rotom
# Type1           Electric
# Name: 532, dtype: object
# 533 Name     RotomWash Rotom
# Type1           Electric
# Name: 533, dtype: object
# 534 Name     RotomFrost Rotom
# Type1            Electric
# Name: 534, dtype: object
# 535 Name     RotomFan Rotom
# Type1          Electric
# Name: 535, dtype: object
# 536 Name     RotomMow Rotom
# Type1          Electric
# Name: 536, dtype: object
# 537 Name        Uxie
# Type1    Psychic
# Name: 537, dtype: object
# 538 Name     Mesprit
# Type1    Psychic
# Name: 538, dtype: object
# 539 Name       Azelf
# Type1    Psychic
# Name: 539, dtype: object
# 540 Name     Dialga
# Type1     Steel
# Name: 540, dtype: object
# 541 Name     Palkia
# Type1     Water
# Name: 541, dtype: object
# 542 Name     Heatran
# Type1       Fire
# Name: 542, dtype: object
# 543 Name     Regigigas
# Type1       Normal
# Name: 543, dtype: object
# 544 Name     GiratinaAltered Forme
# Type1                    Ghost
# Name: 544, dtype: object
# 545 Name     GiratinaOrigin Forme
# Type1                   Ghost
# Name: 545, dtype: object
# 546 Name     Cresselia
# Type1      Psychic
# Name: 546, dtype: object
# 547 Name     Phione
# Type1     Water
# Name: 547, dtype: object
# 548 Name     Manaphy
# Type1      Water
# Name: 548, dtype: object
# 549 Name     Darkrai
# Type1       Dark
# Name: 549, dtype: object
# 550 Name     ShayminLand Forme
# Type1                Grass
# Name: 550, dtype: object
# 551 Name     ShayminSky Forme
# Type1               Grass
# Name: 551, dtype: object
# 552 Name     Arceus
# Type1    Normal
# Name: 552, dtype: object
# 553 Name     Victini
# Type1    Psychic
# Name: 553, dtype: object
# 554 Name     Snivy
# Type1    Grass
# Name: 554, dtype: object
# 555 Name     Servine
# Type1      Grass
# Name: 555, dtype: object
# 556 Name     Serperior
# Type1        Grass
# Name: 556, dtype: object
# 557 Name     Tepig
# Type1     Fire
# Name: 557, dtype: object
# 558 Name     Pignite
# Type1       Fire
# Name: 558, dtype: object
# 559 Name     Emboar
# Type1      Fire
# Name: 559, dtype: object
# 560 Name     Oshawott
# Type1       Water
# Name: 560, dtype: object
# 561 Name     Dewott
# Type1     Water
# Name: 561, dtype: object
# 562 Name     Samurott
# Type1       Water
# Name: 562, dtype: object
# 563 Name     Patrat
# Type1    Normal
# Name: 563, dtype: object
# 564 Name     Watchog
# Type1     Normal
# Name: 564, dtype: object
# 565 Name     Lillipup
# Type1      Normal
# Name: 565, dtype: object
# 566 Name     Herdier
# Type1     Normal
# Name: 566, dtype: object
# 567 Name     Stoutland
# Type1       Normal
# Name: 567, dtype: object
# 568 Name     Purrloin
# Type1        Dark
# Name: 568, dtype: object
# 569 Name     Liepard
# Type1       Dark
# Name: 569, dtype: object
# 570 Name     Pansage
# Type1      Grass
# Name: 570, dtype: object
# 571 Name     Simisage
# Type1       Grass
# Name: 571, dtype: object
# 572 Name     Pansear
# Type1       Fire
# Name: 572, dtype: object
# 573 Name     Simisear
# Type1        Fire
# Name: 573, dtype: object
# 574 Name     Panpour
# Type1      Water
# Name: 574, dtype: object
# 575 Name     Simipour
# Type1       Water
# Name: 575, dtype: object
# 576 Name       Munna
# Type1    Psychic
# Name: 576, dtype: object
# 577 Name     Musharna
# Type1     Psychic
# Name: 577, dtype: object
# 578 Name     Pidove
# Type1    Normal
# Name: 578, dtype: object
# 579 Name     Tranquill
# Type1       Normal
# Name: 579, dtype: object
# 580 Name     Unfezant
# Type1      Normal
# Name: 580, dtype: object
# 581 Name      Blitzle
# Type1    Electric
# Name: 581, dtype: object
# 582 Name     Zebstrika
# Type1     Electric
# Name: 582, dtype: object
# 583 Name     Roggenrola
# Type1          Rock
# Name: 583, dtype: object
# 584 Name     Boldore
# Type1       Rock
# Name: 584, dtype: object
# 585 Name     Gigalith
# Type1        Rock
# Name: 585, dtype: object
# 586 Name      Woobat
# Type1    Psychic
# Name: 586, dtype: object
# 587 Name     Swoobat
# Type1    Psychic
# Name: 587, dtype: object
# 588 Name     Drilbur
# Type1     Ground
# Name: 588, dtype: object
# 589 Name     Excadrill
# Type1       Ground
# Name: 589, dtype: object
# 590 Name     Audino
# Type1    Normal
# Name: 590, dtype: object
# 591 Name     AudinoMega Audino
# Type1               Normal
# Name: 591, dtype: object
# 592 Name      Timburr
# Type1    Fighting
# Name: 592, dtype: object
# 593 Name      Gurdurr
# Type1    Fighting
# Name: 593, dtype: object
# 594 Name     Conkeldurr
# Type1      Fighting
# Name: 594, dtype: object
# 595 Name     Tympole
# Type1      Water
# Name: 595, dtype: object
# 596 Name     Palpitoad
# Type1        Water
# Name: 596, dtype: object
# 597 Name     Seismitoad
# Type1         Water
# Name: 597, dtype: object
# 598 Name        Throh
# Type1    Fighting
# Name: 598, dtype: object
# 599 Name         Sawk
# Type1    Fighting
# Name: 599, dtype: object
# 600 Name     Sewaddle
# Type1         Bug
# Name: 600, dtype: object
# 601 Name     Swadloon
# Type1         Bug
# Name: 601, dtype: object
# 602 Name     Leavanny
# Type1         Bug
# Name: 602, dtype: object
# 603 Name     Venipede
# Type1         Bug
# Name: 603, dtype: object
# 604 Name     Whirlipede
# Type1           Bug
# Name: 604, dtype: object
# 605 Name     Scolipede
# Type1          Bug
# Name: 605, dtype: object
# 606 Name     Cottonee
# Type1       Grass
# Name: 606, dtype: object
# 607 Name     Whimsicott
# Type1         Grass
# Name: 607, dtype: object
# 608 Name     Petilil
# Type1      Grass
# Name: 608, dtype: object
# 609 Name     Lilligant
# Type1        Grass
# Name: 609, dtype: object
# 610 Name     Basculin
# Type1       Water
# Name: 610, dtype: object
# 611 Name     Sandile
# Type1     Ground
# Name: 611, dtype: object
# 612 Name     Krokorok
# Type1      Ground
# Name: 612, dtype: object
# 613 Name     Krookodile
# Type1        Ground
# Name: 613, dtype: object
# 614 Name     Darumaka
# Type1        Fire
# Name: 614, dtype: object
# 615 Name     DarmanitanStandard Mode
# Type1                       Fire
# Name: 615, dtype: object
# 616 Name     DarmanitanZen Mode
# Type1                  Fire
# Name: 616, dtype: object
# 617 Name     Maractus
# Type1       Grass
# Name: 617, dtype: object
# 618 Name     Dwebble
# Type1        Bug
# Name: 618, dtype: object
# 619 Name     Crustle
# Type1        Bug
# Name: 619, dtype: object
# 620 Name     Scraggy
# Type1       Dark
# Name: 620, dtype: object
# 621 Name     Scrafty
# Type1       Dark
# Name: 621, dtype: object
# 622 Name     Sigilyph
# Type1     Psychic
# Name: 622, dtype: object
# 623 Name     Yamask
# Type1     Ghost
# Name: 623, dtype: object
# 624 Name     Cofagrigus
# Type1         Ghost
# Name: 624, dtype: object
# 625 Name     Tirtouga
# Type1       Water
# Name: 625, dtype: object
# 626 Name     Carracosta
# Type1         Water
# Name: 626, dtype: object
# 627 Name     Archen
# Type1      Rock
# Name: 627, dtype: object
# 628 Name     Archeops
# Type1        Rock
# Name: 628, dtype: object
# 629 Name     Trubbish
# Type1      Poison
# Name: 629, dtype: object
# 630 Name     Garbodor
# Type1      Poison
# Name: 630, dtype: object
# 631 Name     Zorua
# Type1     Dark
# Name: 631, dtype: object
# 632 Name     Zoroark
# Type1       Dark
# Name: 632, dtype: object
# 633 Name     Minccino
# Type1      Normal
# Name: 633, dtype: object
# 634 Name     Cinccino
# Type1      Normal
# Name: 634, dtype: object
# 635 Name     Gothita
# Type1    Psychic
# Name: 635, dtype: object
# 636 Name     Gothorita
# Type1      Psychic
# Name: 636, dtype: object
# 637 Name     Gothitelle
# Type1       Psychic
# Name: 637, dtype: object
# 638 Name     Solosis
# Type1    Psychic
# Name: 638, dtype: object
# 639 Name     Duosion
# Type1    Psychic
# Name: 639, dtype: object
# 640 Name     Reuniclus
# Type1      Psychic
# Name: 640, dtype: object
# 641 Name     Ducklett
# Type1       Water
# Name: 641, dtype: object
# 642 Name     Swanna
# Type1     Water
# Name: 642, dtype: object
# 643 Name     Vanillite
# Type1          Ice
# Name: 643, dtype: object
# 644 Name     Vanillish
# Type1          Ice
# Name: 644, dtype: object
# 645 Name     Vanilluxe
# Type1          Ice
# Name: 645, dtype: object
# 646 Name     Deerling
# Type1      Normal
# Name: 646, dtype: object
# 647 Name     Sawsbuck
# Type1      Normal
# Name: 647, dtype: object
# 648 Name       Emolga
# Type1    Electric
# Name: 648, dtype: object
# 649 Name     Karrablast
# Type1           Bug
# Name: 649, dtype: object
# 650 Name     Escavalier
# Type1           Bug
# Name: 650, dtype: object
# 651 Name     Foongus
# Type1      Grass
# Name: 651, dtype: object
# 652 Name     Amoonguss
# Type1        Grass
# Name: 652, dtype: object
# 653 Name     Frillish
# Type1       Water
# Name: 653, dtype: object
# 654 Name     Jellicent
# Type1        Water
# Name: 654, dtype: object
# 655 Name     Alomomola
# Type1        Water
# Name: 655, dtype: object
# 656 Name     Joltik
# Type1       Bug
# Name: 656, dtype: object
# 657 Name     Galvantula
# Type1           Bug
# Name: 657, dtype: object
# 658 Name     Ferroseed
# Type1        Grass
# Name: 658, dtype: object
# 659 Name     Ferrothorn
# Type1         Grass
# Name: 659, dtype: object
# 660 Name     Klink
# Type1    Steel
# Name: 660, dtype: object
# 661 Name     Klang
# Type1    Steel
# Name: 661, dtype: object
# 662 Name     Klinklang
# Type1        Steel
# Name: 662, dtype: object
# 663 Name       Tynamo
# Type1    Electric
# Name: 663, dtype: object
# 664 Name     Eelektrik
# Type1     Electric
# Name: 664, dtype: object
# 665 Name     Eelektross
# Type1      Electric
# Name: 665, dtype: object
# 666 Name      Elgyem
# Type1    Psychic
# Name: 666, dtype: object
# 667 Name     Beheeyem
# Type1     Psychic
# Name: 667, dtype: object
# 668 Name     Litwick
# Type1      Ghost
# Name: 668, dtype: object
# 669 Name     Lampent
# Type1      Ghost
# Name: 669, dtype: object
# 670 Name     Chandelure
# Type1         Ghost
# Name: 670, dtype: object
# 671 Name       Axew
# Type1    Dragon
# Name: 671, dtype: object
# 672 Name     Fraxure
# Type1     Dragon
# Name: 672, dtype: object
# 673 Name     Haxorus
# Type1     Dragon
# Name: 673, dtype: object
# 674 Name     Cubchoo
# Type1        Ice
# Name: 674, dtype: object
# 675 Name     Beartic
# Type1        Ice
# Name: 675, dtype: object
# 676 Name     Cryogonal
# Type1          Ice
# Name: 676, dtype: object
# 677 Name     Shelmet
# Type1        Bug
# Name: 677, dtype: object
# 678 Name     Accelgor
# Type1         Bug
# Name: 678, dtype: object
# 679 Name     Stunfisk
# Type1      Ground
# Name: 679, dtype: object
# 680 Name      Mienfoo
# Type1    Fighting
# Name: 680, dtype: object
# 681 Name     Mienshao
# Type1    Fighting
# Name: 681, dtype: object
# 682 Name     Druddigon
# Type1       Dragon
# Name: 682, dtype: object
# 683 Name     Golett
# Type1    Ground
# Name: 683, dtype: object
# 684 Name     Golurk
# Type1    Ground
# Name: 684, dtype: object
# 685 Name     Pawniard
# Type1        Dark
# Name: 685, dtype: object
# 686 Name     Bisharp
# Type1       Dark
# Name: 686, dtype: object
# 687 Name     Bouffalant
# Type1        Normal
# Name: 687, dtype: object
# 688 Name     Rufflet
# Type1     Normal
# Name: 688, dtype: object
# 689 Name     Braviary
# Type1      Normal
# Name: 689, dtype: object
# 690 Name     Vullaby
# Type1       Dark
# Name: 690, dtype: object
# 691 Name     Mandibuzz
# Type1         Dark
# Name: 691, dtype: object
# 692 Name     Heatmor
# Type1       Fire
# Name: 692, dtype: object
# 693 Name     Durant
# Type1       Bug
# Name: 693, dtype: object
# 694 Name     Deino
# Type1     Dark
# Name: 694, dtype: object
# 695 Name     Zweilous
# Type1        Dark
# Name: 695, dtype: object
# 696 Name     Hydreigon
# Type1         Dark
# Name: 696, dtype: object
# 697 Name     Larvesta
# Type1         Bug
# Name: 697, dtype: object
# 698 Name     Volcarona
# Type1          Bug
# Name: 698, dtype: object
# 699 Name     Cobalion
# Type1       Steel
# Name: 699, dtype: object
# 700 Name     Terrakion
# Type1         Rock
# Name: 700, dtype: object
# 701 Name     Virizion
# Type1       Grass
# Name: 701, dtype: object
# 702 Name     TornadusIncarnate Forme
# Type1                     Flying
# Name: 702, dtype: object
# 703 Name     TornadusTherian Forme
# Type1                   Flying
# Name: 703, dtype: object
# 704 Name     ThundurusIncarnate Forme
# Type1                    Electric
# Name: 704, dtype: object
# 705 Name     ThundurusTherian Forme
# Type1                  Electric
# Name: 705, dtype: object
# 706 Name     Reshiram
# Type1      Dragon
# Name: 706, dtype: object
# 707 Name     Zekrom
# Type1    Dragon
# Name: 707, dtype: object
# 708 Name     LandorusIncarnate Forme
# Type1                     Ground
# Name: 708, dtype: object
# 709 Name     LandorusTherian Forme
# Type1                   Ground
# Name: 709, dtype: object
# 710 Name     Kyurem
# Type1    Dragon
# Name: 710, dtype: object
# 711 Name     KyuremBlack Kyurem
# Type1                Dragon
# Name: 711, dtype: object
# 712 Name     KyuremWhite Kyurem
# Type1                Dragon
# Name: 712, dtype: object
# 713 Name     KeldeoOrdinary Forme
# Type1                   Water
# Name: 713, dtype: object
# 714 Name     KeldeoResolute Forme
# Type1                   Water
# Name: 714, dtype: object
# 715 Name     MeloettaAria Forme
# Type1                Normal
# Name: 715, dtype: object
# 716 Name     MeloettaPirouette Forme
# Type1                     Normal
# Name: 716, dtype: object
# 717 Name     Genesect
# Type1         Bug
# Name: 717, dtype: object
# 718 Name     Chespin
# Type1      Grass
# Name: 718, dtype: object
# 719 Name     Quilladin
# Type1        Grass
# Name: 719, dtype: object
# 720 Name     Chesnaught
# Type1         Grass
# Name: 720, dtype: object
# 721 Name     Fennekin
# Type1        Fire
# Name: 721, dtype: object
# 722 Name     Braixen
# Type1       Fire
# Name: 722, dtype: object
# 723 Name     Delphox
# Type1       Fire
# Name: 723, dtype: object
# 724 Name     Froakie
# Type1      Water
# Name: 724, dtype: object
# 725 Name     Frogadier
# Type1        Water
# Name: 725, dtype: object
# 726 Name     Greninja
# Type1       Water
# Name: 726, dtype: object
# 727 Name     Bunnelby
# Type1      Normal
# Name: 727, dtype: object
# 728 Name     Diggersby
# Type1       Normal
# Name: 728, dtype: object
# 729 Name     Fletchling
# Type1        Normal
# Name: 729, dtype: object
# 730 Name     Fletchinder
# Type1           Fire
# Name: 730, dtype: object
# 731 Name     Talonflame
# Type1          Fire
# Name: 731, dtype: object
# 732 Name     Scatterbug
# Type1           Bug
# Name: 732, dtype: object
# 733 Name     Spewpa
# Type1       Bug
# Name: 733, dtype: object
# 734 Name     Vivillon
# Type1         Bug
# Name: 734, dtype: object
# 735 Name     Litleo
# Type1      Fire
# Name: 735, dtype: object
# 736 Name     Pyroar
# Type1      Fire
# Name: 736, dtype: object
# 737 Name     FlabÃ©bÃ©
# Type1        Fairy
# Name: 737, dtype: object
# 738 Name     Floette
# Type1      Fairy
# Name: 738, dtype: object
# 739 Name     Florges
# Type1      Fairy
# Name: 739, dtype: object
# 740 Name     Skiddo
# Type1     Grass
# Name: 740, dtype: object
# 741 Name     Gogoat
# Type1     Grass
# Name: 741, dtype: object
# 742 Name      Pancham
# Type1    Fighting
# Name: 742, dtype: object
# 743 Name      Pangoro
# Type1    Fighting
# Name: 743, dtype: object
# 744 Name     Furfrou
# Type1     Normal
# Name: 744, dtype: object
# 745 Name      Espurr
# Type1    Psychic
# Name: 745, dtype: object
# 746 Name     MeowsticMale
# Type1         Psychic
# Name: 746, dtype: object
# 747 Name     MeowsticFemale
# Type1           Psychic
# Name: 747, dtype: object
# 748 Name     Honedge
# Type1      Steel
# Name: 748, dtype: object
# 749 Name     Doublade
# Type1       Steel
# Name: 749, dtype: object
# 750 Name     AegislashBlade Forme
# Type1                   Steel
# Name: 750, dtype: object
# 751 Name     AegislashShield Forme
# Type1                    Steel
# Name: 751, dtype: object
# 752 Name     Spritzee
# Type1       Fairy
# Name: 752, dtype: object
# 753 Name     Aromatisse
# Type1         Fairy
# Name: 753, dtype: object
# 754 Name     Swirlix
# Type1      Fairy
# Name: 754, dtype: object
# 755 Name     Slurpuff
# Type1       Fairy
# Name: 755, dtype: object
# 756 Name     Inkay
# Type1     Dark
# Name: 756, dtype: object
# 757 Name     Malamar
# Type1       Dark
# Name: 757, dtype: object
# 758 Name     Binacle
# Type1       Rock
# Name: 758, dtype: object
# 759 Name     Barbaracle
# Type1          Rock
# Name: 759, dtype: object
# 760 Name     Skrelp
# Type1    Poison
# Name: 760, dtype: object
# 761 Name     Dragalge
# Type1      Poison
# Name: 761, dtype: object
# 762 Name     Clauncher
# Type1        Water
# Name: 762, dtype: object
# 763 Name     Clawitzer
# Type1        Water
# Name: 763, dtype: object
# 764 Name     Helioptile
# Type1      Electric
# Name: 764, dtype: object
# 765 Name     Heliolisk
# Type1     Electric
# Name: 765, dtype: object
# 766 Name     Tyrunt
# Type1      Rock
# Name: 766, dtype: object
# 767 Name     Tyrantrum
# Type1         Rock
# Name: 767, dtype: object
# 768 Name     Amaura
# Type1      Rock
# Name: 768, dtype: object
# 769 Name     Aurorus
# Type1       Rock
# Name: 769, dtype: object
# 770 Name     Sylveon
# Type1      Fairy
# Name: 770, dtype: object
# 771 Name     Hawlucha
# Type1    Fighting
# Name: 771, dtype: object
# 772 Name      Dedenne
# Type1    Electric
# Name: 772, dtype: object
# 773 Name     Carbink
# Type1       Rock
# Name: 773, dtype: object
# 774 Name      Goomy
# Type1    Dragon
# Name: 774, dtype: object
# 775 Name     Sliggoo
# Type1     Dragon
# Name: 775, dtype: object
# 776 Name     Goodra
# Type1    Dragon
# Name: 776, dtype: object
# 777 Name     Klefki
# Type1     Steel
# Name: 777, dtype: object
# 778 Name     Phantump
# Type1       Ghost
# Name: 778, dtype: object
# 779 Name     Trevenant
# Type1        Ghost
# Name: 779, dtype: object
# 780 Name     PumpkabooAverage Size
# Type1                    Ghost
# Name: 780, dtype: object
# 781 Name     PumpkabooSmall Size
# Type1                  Ghost
# Name: 781, dtype: object
# 782 Name     PumpkabooLarge Size
# Type1                  Ghost
# Name: 782, dtype: object
# 783 Name     PumpkabooSuper Size
# Type1                  Ghost
# Name: 783, dtype: object
# 784 Name     GourgeistAverage Size
# Type1                    Ghost
# Name: 784, dtype: object
# 785 Name     GourgeistSmall Size
# Type1                  Ghost
# Name: 785, dtype: object
# 786 Name     GourgeistLarge Size
# Type1                  Ghost
# Name: 786, dtype: object
# 787 Name     GourgeistSuper Size
# Type1                  Ghost
# Name: 787, dtype: object
# 788 Name     Bergmite
# Type1         Ice
# Name: 788, dtype: object
# 789 Name     Avalugg
# Type1        Ice
# Name: 789, dtype: object
# 790 Name     Noibat
# Type1    Flying
# Name: 790, dtype: object
# 791 Name     Noivern
# Type1     Flying
# Name: 791, dtype: object
# 792 Name     Xerneas
# Type1      Fairy
# Name: 792, dtype: object
# 793 Name     Yveltal
# Type1       Dark
# Name: 793, dtype: object
# 794 Name     Zygarde50% Forme
# Type1              Dragon
# Name: 794, dtype: object
# 795 Name     Diancie
# Type1       Rock
# Name: 795, dtype: object
# 796 Name     DiancieMega Diancie
# Type1                   Rock
# Name: 796, dtype: object
# 797 Name     HoopaHoopa Confined
# Type1                Psychic
# Name: 797, dtype: object
# 798 Name     HoopaHoopa Unbound
# Type1               Psychic
# Name: 798, dtype: object
# 799 Name     Volcanion
# Type1         Fire
# Name: 799, dtype: object

# %% [markdown]
# # Consultas

# %%
pokemon.describe()
# Out:
#               Num          HP      Attack     Defense       SpAtk       SpDef  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
# La sentencia .loc (locate)

#pokemon.loc[pokemon['Type1'] == 'Grass']
pokemon.loc[(pokemon['Type1'] == 'Grass') & (pokemon['Type2'] == 'Poison')]
# Out:
#      Num                   Name  Type1   Type2   HP  ...  SpAtk  SpDef  Speed  \
# 0      1              Bulbasaur  Grass  Poison   45  ...     65     65     45
# 1      2                Ivysaur  Grass  Poison   60  ...     80     80     60
# 2      3               Venusaur  Grass  Poison   80  ...    100    100     80
# 3      3  VenusaurMega Venusaur  Grass  Poison   80  ...    122    120     80
# 48    43                 Oddish  Grass  Poison   45  ...     75     65     30
# ..   ...                    ...    ...     ...  ...  ...    ...    ...    ...
# 344  315                Roselia  Grass  Poison   50  ...    100     80     65
# 451  406                  Budew  Grass  Poison   40  ...     50     70     55
# 452  407               Roserade  Grass  Poison   60  ...    125    105     90
# 651  590                Foongus  Grass  Poison   69  ...     55     55     15
# 652  591              Amoonguss  Grass  Poison  114  ...     85     80     30
#
#      Generation  Legendary
# 0             1      False
# 1             1      False
# 2             1      False
# 3             1      False
# 48            1      False
# ..          ...        ...
# 344           3      False
# 451           4      False
# 452           4      False
# 651           5      False
# 652           5      False
#
# [15 rows x 12 columns]

# %%
# Ordenar tablas

pokemon.sort_values('Defense', ascending=False).head()
# Out:
#      Num                 Name  Type1   Type2  HP  ...  SpAtk  SpDef  Speed  \
# 230  213              Shuckle    Bug    Rock  20  ...     10    230      5
# 224  208  SteelixMega Steelix  Steel  Ground  75  ...     55     95     30
# 333  306    AggronMega Aggron  Steel     NaN  70  ...     60     80     50
# 223  208              Steelix  Steel  Ground  75  ...     55     65     30
# 414  377             Regirock   Rock     NaN  80  ...     50    100     50
#
#      Generation  Legendary
# 230           2      False
# 224           2      False
# 333           3      False
# 223           2      False
# 414           3       True
#
# [5 rows x 12 columns]

# %%
ghost_pks = pokemon.loc[pokemon['Type1'] == 'Ghost'].sort_values(['Generation', 'Speed'], ascending=False)

ghost_pks = ghost_pks.reset_index(drop=True)

#ghost_pks.drop(columns=['index'])

ghost_pks
# Out:
#     Num                   Name  Type1   Type2  HP  ...  SpAtk  SpDef  Speed  \
# 0   711    GourgeistSmall Size  Ghost   Grass  55  ...     58     75     99
# 1   711  GourgeistAverage Size  Ghost   Grass  65  ...     58     75     84
# 2   711    GourgeistLarge Size  Ghost   Grass  75  ...     58     75     69
# 3   709              Trevenant  Ghost   Grass  85  ...     65     82     56
# 4   710    PumpkabooSmall Size  Ghost   Grass  44  ...     44     55     56
# ..  ...                    ...    ...     ...  ..  ...    ...    ...    ...
# 27  200             Misdreavus  Ghost     NaN  60  ...     85     85     85
# 28   94      GengarMega Gengar  Ghost  Poison  60  ...    170     95    130
# 29   94                 Gengar  Ghost  Poison  60  ...    130     75    110
# 30   93                Haunter  Ghost  Poison  45  ...    115     55     95
# 31   92                 Gastly  Ghost  Poison  30  ...    100     35     80
#
#     Generation  Legendary
# 0            6      False
# 1            6      False
# 2            6      False
# 3            6      False
# 4            6      False
# ..         ...        ...
# 27           2      False
# 28           1      False
# 29           1      False
# 30           1      False
# 31           1      False
#
# [32 rows x 12 columns]

# %%
pokemon.loc[~pokemon['Name'].str.contains('Mega')]
# Out:
#      Num                 Name    Type1   Type2   HP  ...  SpAtk  SpDef  Speed  \
# 0      1            Bulbasaur    Grass  Poison   45  ...     65     65     45
# 1      2              Ivysaur    Grass  Poison   60  ...     80     80     60
# 2      3             Venusaur    Grass  Poison   80  ...    100    100     80
# 4      4           Charmander     Fire     NaN   39  ...     60     50     65
# 5      5           Charmeleon     Fire     NaN   58  ...     80     65     80
# ..   ...                  ...      ...     ...  ...  ...    ...    ...    ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108  ...     81     95     95
# 795  719              Diancie     Rock   Fairy   50  ...    100    150     50
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80  ...    150    130     70
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80  ...    170    130     80
# 799  721            Volcanion     Fire   Water   80  ...    130     90     70
#
#      Generation  Legendary
# 0             1      False
# 1             1      False
# 2             1      False
# 4             1      False
# 5             1      False
# ..          ...        ...
# 794           6       True
# 795           6       True
# 797           6       True
# 798           6       True
# 799           6       True
#
# [751 rows x 12 columns]

# %%
# Hacer consultas de cadenas de texto usando expresiones regulares
import re 

pokemon.loc[pokemon['Name'].str.contains('f.a+', regex=True, flags = re.I)]
# Out:
#      Num        Name     Type1   Type2  HP  ...  SpAtk  SpDef  Speed  \
# 27    22      Fearow    Normal  Flying  65  ...     61     61    100
# 147  136     Flareon      Fire     NaN  65  ...     95    110     65
# 187  173      Cleffa     Fairy     NaN  50  ...     45     55     15
# 194  180     Flaaffy  Electric     NaN  70  ...     80     60     45
# 672  611     Fraxure    Dragon     NaN  66  ...     40     50     67
# 687  626  Bouffalant    Normal     NaN  95  ...     40     95     55
# 731  663  Talonflame      Fire  Flying  78  ...     74     69    126
# 737  669   FlabÃ©bÃ©     Fairy     NaN  44  ...     61     79     42
#
#      Generation  Legendary
# 27            1      False
# 147           1      False
# 187           2      False
# 194           2      False
# 672           5      False
# 687           5      False
# 731           6      False
# 737           6      False
#
# [8 rows x 12 columns]

# %% [markdown]
# # Editar columnas

# %%
pokemon["Attack-Defense Ratio"] = pokemon["Attack"]/pokemon["Defense"]

# %%
pokemon
# Out:
#      Num                   Name    Type1   Type2  HP  ...  SpDef  Speed  \
# 0      1              Bulbasaur    Grass  Poison  45  ...     65     45
# 1      2                Ivysaur    Grass  Poison  60  ...     80     60
# 2      3               Venusaur    Grass  Poison  80  ...    100     80
# 3      3  VenusaurMega Venusaur    Grass  Poison  80  ...    120     80
# 4      4             Charmander     Fire     NaN  39  ...     50     65
# ..   ...                    ...      ...     ...  ..  ...    ...    ...
# 795  719                Diancie     Rock   Fairy  50  ...    150     50
# 796  719    DiancieMega Diancie     Rock   Fairy  50  ...    110    110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80  ...    130     70
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80  ...    130     80
# 799  721              Volcanion     Fire   Water  80  ...     90     70
#
#      Generation  Legendary  Attack-Defense Ratio
# 0             1      False              1.000000
# 1             1      False              0.984127
# 2             1      False              0.987952
# 3             1      False              0.813008
# 4             1      False              1.209302
# ..          ...        ...                   ...
# 795           6       True              0.666667
# 796           6       True              1.454545
# 797           6       True              1.833333
# 798           6       True              2.666667
# 799           6       True              0.916667
#
# [800 rows x 13 columns]

# %%
pokemon.loc[pokemon['Type1'] == 'Poison', 'Type1'] = 'Venom'
pokemon.head(100)
# Out:
#     Num                   Name  Type1   Type2   HP  ...  SpDef  Speed  \
# 0     1              Bulbasaur  Grass  Poison   45  ...     65     45
# 1     2                Ivysaur  Grass  Poison   60  ...     80     60
# 2     3               Venusaur  Grass  Poison   80  ...    100     80
# 3     3  VenusaurMega Venusaur  Grass  Poison   80  ...    120     80
# 4     4             Charmander   Fire     NaN   39  ...     50     65
# ..  ...                    ...    ...     ...  ...  ...    ...    ...
# 95   88                 Grimer  Venom     NaN   80  ...     50     25
# 96   89                    Muk  Venom     NaN  105  ...    100     50
# 97   90               Shellder  Water     NaN   30  ...     25     40
# 98   91               Cloyster  Water     Ice   50  ...     45     70
# 99   92                 Gastly  Ghost  Poison   30  ...     35     80
#
#     Generation  Legendary  Attack-Defense Ratio
# 0            1      False              1.000000
# 1            1      False              0.984127
# 2            1      False              0.987952
# 3            1      False              0.813008
# 4            1      False              1.209302
# ..         ...        ...                   ...
# 95           1      False              1.600000
# 96           1      False              1.400000
# 97           1      False              0.650000
# 98           1      False              0.527778
# 99           1      False              1.166667
#
# [100 rows x 13 columns]

# %%
pokemon.loc[pokemon['SpAtk'] >= 130, 'Legendary'] = True
pokemon.head(50)
# Out:
#     Num                   Name   Type1   Type2   HP  ...  SpDef  Speed  \
# 0     1              Bulbasaur   Grass  Poison   45  ...     65     45
# 1     2                Ivysaur   Grass  Poison   60  ...     80     60
# 2     3               Venusaur   Grass  Poison   80  ...    100     80
# 3     3  VenusaurMega Venusaur   Grass  Poison   80  ...    120     80
# 4     4             Charmander    Fire     NaN   39  ...     50     65
# ..  ...                    ...     ...     ...  ...  ...    ...    ...
# 45   40             Wigglytuff  Normal   Fairy  140  ...     50     45
# 46   41                  Zubat   Venom  Flying   40  ...     40     55
# 47   42                 Golbat   Venom  Flying   75  ...     75     90
# 48   43                 Oddish   Grass  Poison   45  ...     65     30
# 49   44                  Gloom   Grass  Poison   60  ...     75     40
#
#     Generation  Legendary  Attack-Defense Ratio
# 0            1      False              1.000000
# 1            1      False              0.984127
# 2            1      False              0.987952
# 3            1      False              0.813008
# 4            1      False              1.209302
# ..         ...        ...                   ...
# 45           1      False              1.555556
# 46           1      False              1.285714
# 47           1      False              1.142857
# 48           1      False              0.909091
# 49           1      False              0.928571
#
# [50 rows x 13 columns]

# %%
pokemon.loc[pokemon['Type1'] == 'Water', ['HP', 'Attack']] = [0, -1]
pokemon.head(100)
# Out:
#     Num                   Name  Type1   Type2   HP  ...  SpDef  Speed  \
# 0     1              Bulbasaur  Grass  Poison   45  ...     65     45
# 1     2                Ivysaur  Grass  Poison   60  ...     80     60
# 2     3               Venusaur  Grass  Poison   80  ...    100     80
# 3     3  VenusaurMega Venusaur  Grass  Poison   80  ...    120     80
# 4     4             Charmander   Fire     NaN   39  ...     50     65
# ..  ...                    ...    ...     ...  ...  ...    ...    ...
# 95   88                 Grimer  Venom     NaN   80  ...     50     25
# 96   89                    Muk  Venom     NaN  105  ...    100     50
# 97   90               Shellder  Water     NaN    0  ...     25     40
# 98   91               Cloyster  Water     Ice    0  ...     45     70
# 99   92                 Gastly  Ghost  Poison   30  ...     35     80
#
#     Generation  Legendary  Attack-Defense Ratio
# 0            1      False              1.000000
# 1            1      False              0.984127
# 2            1      False              0.987952
# 3            1      False              0.813008
# 4            1      False              1.209302
# ..         ...        ...                   ...
# 95           1      False              1.600000
# 96           1      False              1.400000
# 97           1      False              0.650000
# 98           1      False              0.527778
# 99           1      False              1.166667
#
# [100 rows x 13 columns]

# %%
pokemon['Speed'].apply(lambda x : x/2).head(100)
#pokemon['Speed'].head(10)
# Out:
# 0     22.5
# 1     30.0
# 2     40.0
# 3     40.0
# 4     32.5
#       ...
# 95    12.5
# 96    25.0
# 97    20.0
# 98    35.0
# 99    40.0
# Name: Speed, Length: 100, dtype: float64

# %%
pokemon.loc[pokemon['Name'].str.contains('Mega')]['Name'].apply(lambda x : 'Mega ' + x.split(' ')[1] if x != 'Meganium' else x)
# Out:
# 3       Mega Venusaur
# 7      Mega Charizard
# 8      Mega Charizard
# 12     Mega Blastoise
# 19      Mega Beedrill
#             ...
# 498      Mega Lucario
# 511    Mega Abomasnow
# 527      Mega Gallade
# 591       Mega Audino
# 796      Mega Diancie
# Name: Name, Length: 49, dtype: object

# %% [markdown]
# #Agregar columnas

# %%
pokemon['Total Defense'] = pokemon['Defense'] + pokemon['SpDef']
#pokemon = pokemon.drop(columns='Total Defense')
pokemon.head(10)
# Out:
#    Num                       Name  Type1   Type2  HP  ...  Speed  Generation  \
# 0    1                  Bulbasaur  Grass  Poison  45  ...     45           1
# 1    2                    Ivysaur  Grass  Poison  60  ...     60           1
# 2    3                   Venusaur  Grass  Poison  80  ...     80           1
# 3    3      VenusaurMega Venusaur  Grass  Poison  80  ...     80           1
# 4    4                 Charmander   Fire     NaN  39  ...     65           1
# 5    5                 Charmeleon   Fire     NaN  58  ...     80           1
# 6    6                  Charizard   Fire  Flying  78  ...    100           1
# 7    6  CharizardMega Charizard X   Fire  Dragon  78  ...    100           1
# 8    6  CharizardMega Charizard Y   Fire  Flying  78  ...    100           1
# 9    7                   Squirtle  Water     NaN   0  ...     43           1
#
#    Legendary  Attack-Defense Ratio  Total Defense
# 0      False              1.000000            114
# 1      False              0.984127            143
# 2      False              0.987952            183
# 3      False              0.813008            243
# 4      False              1.209302             93
# 5      False              1.103448            123
# 6      False              1.076923            163
# 7       True              1.171171            196
# 8       True              1.333333            193
# 9      False              0.738462            129
#
# [10 rows x 14 columns]

# %%
# Reajuste de columnas
cols = list(pokemon.columns)

pokemon = pokemon[cols[0:9] + [cols[-1]] + cols[9:12]]
pokemon.head()
# Out:
#    Num                   Name  Type1   Type2  HP  ...  SpDef  Total Defense  \
# 0    1              Bulbasaur  Grass  Poison  45  ...     65            114
# 1    2                Ivysaur  Grass  Poison  60  ...     80            143
# 2    3               Venusaur  Grass  Poison  80  ...    100            183
# 3    3  VenusaurMega Venusaur  Grass  Poison  80  ...    120            243
# 4    4             Charmander   Fire     NaN  39  ...     50             93
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False
#
# [5 rows x 13 columns]

# %%
pokemon['Total total'] = pokemon.iloc[:, 4:11].sum(axis = 1)
pokemon.head()
# Out:
#    Num                   Name  Type1   Type2  HP  ...  Total Defense  Speed  \
# 0    1              Bulbasaur  Grass  Poison  45  ...            114     45
# 1    2                Ivysaur  Grass  Poison  60  ...            143     60
# 2    3               Venusaur  Grass  Poison  80  ...            183     80
# 3    3  VenusaurMega Venusaur  Grass  Poison  80  ...            243     80
# 4    4             Charmander   Fire     NaN  39  ...             93     65
#
#    Generation  Legendary  Total total
# 0           1      False          432
# 1           1      False          548
# 2           1      False          708
# 3           1      False          868
# 4           1      False          402
#
# [5 rows x 14 columns]

# %% [markdown]
# # Estadísticas de agregado (groupby)

# %%
pokemon.groupby(['Type1', 'Type2']).mean(numeric_only=True).sort_values('Defense', ascending=False)
# Out:
#                          Num          HP      Attack     Defense       SpAtk  \
# Type1    Type2
# Steel    Ground   208.000000   75.000000  105.000000  215.000000   55.000000
# Ground   Fire     383.000000  100.000000  180.000000  160.000000  150.000000
# Bug      Rock     442.666667   46.666667   56.666667  146.666667   36.666667
# Rock     Steel    432.333333   50.000000   49.666667  143.666667   54.666667
# Steel    Rock     305.000000   60.000000   90.000000  140.000000   50.000000
# ...                      ...         ...         ...         ...         ...
# Bug      Ghost    292.000000    1.000000   90.000000   45.000000   30.000000
# Electric Normal   694.500000   53.000000   46.500000   42.500000   85.000000
# Ghost    Flying   425.500000  120.000000   65.000000   39.000000   75.000000
# Bug      Water    283.000000   40.000000   30.000000   32.000000   50.000000
# Ice      Psychic  181.000000   55.000000   40.000000   25.000000  100.000000
#
#                   ...  Total Defense      Speed  Generation  Legendary  \
# Type1    Type2    ...
# Steel    Ground   ...          295.0  30.000000         2.0        0.0
# Ground   Fire     ...          250.0  90.000000         3.0        1.0
# Bug      Rock     ...          260.0  35.000000         4.0        0.0
# Rock     Steel    ...          269.0  33.333333         4.0        0.0
# Steel    Rock     ...          190.0  40.000000         3.0        0.0
# ...               ...            ...        ...         ...        ...
# Bug      Ghost    ...           75.0  40.000000         3.0        0.0
# Electric Normal   ...          111.0  89.500000         6.0        0.0
# Ghost    Flying   ...           88.0  75.000000         4.0        0.0
# Bug      Water    ...           84.0  65.000000         3.0        0.0
# Ice      Psychic  ...          105.0  80.000000         1.5        0.0
#
#                   Total total
# Type1    Type2
# Steel    Ground    855.000000
# Ground   Fire     1020.000000
# Bug      Rock      695.000000
# Rock     Steel     725.666667
# Steel    Rock      620.000000
# ...                       ...
# Bug      Ghost     311.000000
# Electric Normal    496.000000
# Ghost    Flying    511.000000
# Bug      Water     353.000000
# Ice      Psychic   485.000000
#
# [136 rows x 11 columns]

# %%
pokemon.groupby(['Type1', 'Type2']).count()
# Out:
#                 Num  Name  HP  Attack  Defense  ...  Total Defense  Speed  \
# Type1 Type2                                     ...
# Bug   Electric    2     2   2       2        2  ...              2      2
#       Fighting    2     2   2       2        2  ...              2      2
#       Fire        2     2   2       2        2  ...              2      2
#       Flying     14    14  14      14       14  ...             14     14
#       Ghost       1     1   1       1        1  ...              1      1
# ...             ...   ...  ..     ...      ...  ...            ...    ...
# Water Ice         3     3   3       3        3  ...              3      3
#       Poison      3     3   3       3        3  ...              3      3
#       Psychic     5     5   5       5        5  ...              5      5
#       Rock        4     4   4       4        4  ...              4      4
#       Steel       1     1   1       1        1  ...              1      1
#
#                 Generation  Legendary  Total total
# Type1 Type2
# Bug   Electric           2          2            2
#       Fighting           2          2            2
#       Fire               2          2            2
#       Flying            14         14           14
#       Ghost              1          1            1
# ...                    ...        ...          ...
# Water Ice                3          3            3
#       Poison             3          3            3
#       Psychic            5          5            5
#       Rock               4          4            4
#       Steel              1          1            1
#
# [136 rows x 12 columns]

# %%
type_stats = pokemon.groupby(['Type1']).sum()

# %% [markdown]
# # Guardar

# %%
type_stats.to_csv("type_stats.csv")
ghost_pks.to_excel("ghost_pokemons.xlsx")
